# %%
#loading required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifa=pd.read_csv("Datasets/players_20.csv")

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
for col in fifa.columns:
    print (col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
fifa['nationality'].value_counts()
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
#                ...
# Ethiopia          1
# St Lucia          1
# Puerto Rico       1
# Macau             1
# Hong Kong         1
# Name: nationality, Length: 162, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5]
# Out:
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object')

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]),color="blue")
plt.show()

# %%
player_salary = fifa[['short_name','wage_eur']]
player_salary = player_salary.sort_values(by=['wage_eur'], ascending=False)
player_salary.head(10)
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000
# 19          L. Suárez    355000
# 8           L. Modrić    340000
# 36           T. Kroos    330000
# 17          S. Agüero    300000
# 21    Sergio Busquets    300000

# %%
plt.figure(figsize=(12,5))
plt.bar(list(player_salary['short_name'].value_counts()[0:10].index),list(player_salary['wage_eur'].value_counts()[0:10]))
plt.show()

# %%
#Tallest players and their nationality
fifa[['short_name','height_cm','nationality']].sort_values(by=['height_cm'],ascending=False).head(10)
# Out:
#                 short_name  height_cm     nationality
# 9208               T. Holý        205  Czech Republic
# 8200                 A. Ba        203      Mauritania
# 12808           A. Chapman        203         England
# 3121         C. Pantilimon        203         Romania
# 12864             M. Qvist        203         Denmark
# 17365             M. Casey        203         England
# 5451             L. Traoré        203     Ivory Coast
# 17149            S. Brolin        202          Sweden
# 4868   V. Milinković-Savić        202          Serbia
# 7725           K. Scherpen        202     Netherlands

# %%
fifa['nationality']=='Spain'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
Spain=fifa[fifa['nationality']=='Spain']
Spain.shape
# Out:
# (1035, 104)

# %%
Spain = Spain.sort_values(by=['height_cm'], ascending=False)
Spain.head()
# Out:
#        sofifa_id                                         player_url  \
# 14235     231187  https://sofifa.com/player/231187/hodei-oleaga-...
# 14113     228789  https://sofifa.com/player/228789/robert-lynch-...
# 2486      189709  https://sofifa.com/player/189709/pedro-alcala-...
# 492       146748  https://sofifa.com/player/146748/diego-lopez-r...
# 842       195668  https://sofifa.com/player/195668/joel-robles-b...
#
#            short_name              long_name  age         dob  height_cm  \
# 14235          Oleaga   Hodei Oleaga Alarcia   22  1996-12-29        198
# 14113  Robert Sanchez   Robert Lynch Sanchez   21  1997-11-18        197
# 2486           Alcalá   Pedro Alcalá Guirado   30  1989-03-19        196
# 492       Diego López  Diego López Rodríguez   37  1981-11-03        196
# 842       Joel Robles   Joel Robles Blázquez   29  1990-06-17        195
#
#        weight_kg nationality                     club  ...   lwb   ldm   cdm  \
# ...

# %%
Spain = Spain.sort_values(by=['weight_kg'], ascending = False)
Spain.head()
# Out:
#       sofifa_id                                         player_url  \
# 4556     191688  https://sofifa.com/player/191688/alberto-tomas...
# 1174     183666  https://sofifa.com/player/183666/roberto-jimen...
# 8121     211132  https://sofifa.com/player/211132/andres-tomas-...
# 2486     189709  https://sofifa.com/player/189709/pedro-alcala-...
# 4518     186680  https://sofifa.com/player/186680/raul-fdez-cav...
#
#           short_name                     long_name  age         dob  \
# 4556           Botía   Alberto Tomás Botía Rabasco   30  1989-01-27
# 1174         Roberto          Roberto Jiménez Gago   33  1986-02-10
# 8121   Andrés Prieto    Andrés Tomás Prieto Albert   25  1993-10-17
# 2486          Alcalá          Pedro Alcalá Guirado   30  1989-03-19
# 4518  Raúl Fernández  Raúl Fernández-Cavada Mateos   31  1988-03-13
#
#       height_cm  weight_kg nationality             club  ...   lwb   ldm  \
# 4556        189         96       Spain         Al Hilal  ...  61+2  65+2
# ...

# %%
Spain[['short_name','club','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head(10)
# Out:
#           short_name               club  wage_eur
# 18      Sergio Ramos        Real Madrid    300000
# 21   Sergio Busquets       FC Barcelona    300000
# 29             Piqué       FC Barcelona    285000
# 33       David Silva    Manchester City    265000
# 62              Isco        Real Madrid    245000
# 51        Jordi Alba       FC Barcelona    240000
# 94          Carvajal        Real Madrid    205000
# 14            De Gea  Manchester United    205000
# 52            Thiago  FC Bayern München    180000
# 403    Lucas Vázquez        Real Madrid    180000

# %% [markdown]
# #### Sergio Ramos is the most paid Spanish footballer and belongs to Real Madrid

# %%
player_shooting = fifa[['short_name','club','shooting']].sort_values(by=['shooting'],ascending=False)
player_shooting.head()
# Out:
#             short_name               club  shooting
# 1    Cristiano Ronaldo           Juventus      93.0
# 0             L. Messi       FC Barcelona      92.0
# 12             H. Kane  Tottenham Hotspur      91.0
# 17           S. Agüero    Manchester City      90.0
# 205    F. Quagliarella          Sampdoria      89.0

# %%
player_defending = fifa[['short_name','club','defending']].sort_values(by=['defending'],ascending=False)
player_defending.head()
# Out:
#       short_name               club  defending
# 16  G. Chiellini           Juventus       90.0
# 7    V. van Dijk          Liverpool       90.0
# 11  K. Koulibaly             Napoli       89.0
# 35      D. Godín              Inter       89.0
# 49    M. Hummels  Borussia Dortmund       89.0

# %%
juventus = fifa[fifa['club']=='Juventus']

# %%
juventus[['short_name','nationality','wage_eur','shooting']].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#            short_name         nationality  wage_eur  shooting
# 1   Cristiano Ronaldo            Portugal    405000      93.0
# 23          P. Dybala           Argentina    215000      82.0
# 16       G. Chiellini               Italy    215000      46.0
# 65          M. Pjanić  Bosnia Herzegovina    180000      68.0
# 98         G. Higuaín           Argentina    175000      85.0

# %%
juventus[['short_name','nationality','wage_eur','shooting']].sort_values(by=['shooting'],ascending = False).head()
# Out:
#             short_name nationality  wage_eur  shooting
# 1    Cristiano Ronaldo    Portugal    405000      93.0
# 98          G. Higuaín   Argentina    175000      85.0
# 23           P. Dybala   Argentina    215000      82.0
# 141       M. Mandžukić     Croatia    160000      80.0
# 220          A. Ramsey       Wales    140000      77.0
